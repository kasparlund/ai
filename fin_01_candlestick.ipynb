# %%
#default_exp finance.graphics

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# export
from math import pi

import pandas as pd

from bokeh.io import output_notebook, show
from bokeh.plotting import figure #, output_file
from bokeh.sampledata.stocks import MSFT
output_notebook() #inline plotting
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# export
[DATE,OPEN,HIGH,LOW,CLOSE] = ["date","open","high","low", "close"]

def plotCandlestick(df, ohlc_columns=[DATE,OPEN,HIGH,LOW,CLOSE], title=None, width=None, height=None ):
    inc = df[CLOSE] > df[OPEN]
    dec = df[OPEN]  > df[CLOSE]
    w   = 12*60*60*1000 # half day in ms

    TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
    
    if height is None:
        p = figure(x_axis_type="datetime", tools=TOOLS, plot_width=width, title = title)
    else: 
        p = figure(x_axis_type="datetime", tools=TOOLS, plot_width=width, plot_height=height, title = title)
    p.xaxis.major_label_orientation = pi/4
    p.grid.grid_line_alpha=0.3

    p.segment(df[DATE], df[HIGH], df[DATE], df[LOW], color="black")
    p.vbar(df.loc[inc,DATE], w, df.loc[inc,OPEN], df.loc[inc,CLOSE], fill_color="#D5E1DD", line_color="black")
    p.vbar(df.loc[dec,DATE], w, df.loc[dec,OPEN], df.loc[dec,CLOSE], fill_color="#F2583E", line_color="black")

    show(p)  # open a browser

# %%
df = pd.DataFrame(MSFT)[:50]
df["date"] = pd.to_datetime(df["date"])
plotCandlestick(df, title="MSFT Candlestick", width=1000, height=200)
# Out:
#   <div class="bk-root" id="118f1dba-1e18-4e55-a019-1f6fcf4c052b" data-root-id="1003"></div>

# %%
import matplotlib.pylab as plt
import numpy as np
x = np.linspace(-np.pi, np.pi, 201)
plt.plot(x, np.sin(x))
plt.xlabel('Angle [rad]')
plt.ylabel('sin(x)')
plt.axis('tight')
plt.show()

# %%
#hide
from nbdev.export import notebook2script
notebook2script()
# Out:
# Converted 00_test.ipynb.
# Converted 01_data.external.ipynb.
# Converted 02_lists.ipynb.
# Converted 03_images.ipynb.
# Converted 05_Learner.ipynb.
# Converted 05_model.ipynb.
# Converted 06_modelmanger.ipynb.
# Converted 07_optimizers.ipynb.
# Converted app_image_01_mnist_optimizers.ipynb.
# Converted app_image_02_imagenette_optimizers.ipynb.
# Converted fin_01_candlestick.ipynb.
# Converted fin_02_simfin_data.ipynb.
# Converted index.ipynb.
